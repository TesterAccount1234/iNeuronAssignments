# %% [markdown]
# <aside>
# 💡 Question-1
#
# You are given a binary tree. The binary tree is represented using the TreeNode class. Each TreeNode has an integer value and left and right children, represented using the TreeNode class itself. Convert this binary tree into a binary search tree.
#
# Input:
#
#         10
#
#        /   \
#
#      2      7
#
#    /   \
#
#  8      4
#
# Output:
#
#         8
#
#       /   \
#
#     4     10
#
#   /   \
#
# 2      7
#
# </aside>

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def build(root, result):
    inorder_traversal(root, result)
    result.sort()
    build_bst(result)
    return root

def inorder_traversal(root, result):
    if root is None:
        return
    inorder_traversal(root.left, result)
    result.append(root.val)
    inorder_traversal(root.right, result)


def build_bst(result):
    if not result:
        return None
    
    mid = len(result) // 2
    root1 = TreeNode(result[mid])

    root1.left = build_bst(result[:mid])
    root1.right = build_bst(result[mid+1:])
    return root1

root = TreeNode(10)
root.left = TreeNode(2)
root.right = TreeNode(7)
root.left.left = TreeNode(8)
root.left.right = TreeNode(4)

result = []
root1 = build(root, result)

def preorderTraversal(root1):
    if root1 is None:
        return 
    
    print(root1.val)
    preorderTraversal(root1.left)
    preorderTraversal(root1.right)

preorderTraversal(root1)
# Out:
# 10
# 2
# 8
# 4
# 7

# %% [markdown]
# <aside>
# 💡 Question-2:
#
# Given a Binary Search Tree with all unique values and two keys. Find the distance between two nodes in BST. The given keys always exist in BST.
#
# Example:
#
# Consider the following BST:
#
# </aside>
#
# **Input-1:**
#
# n = 9
#
# values = [8, 3, 1, 6, 4, 7, 10, 14,13]
#
# node-1 = 6
#
# node-2 = 14
#
# **Output-1:**
#
# The distance between the two keys = 4
#
# **Input-2:**
#
# n = 9
#
# values = [8, 3, 1, 6, 4, 7, 10, 14,13]
#
# node-1 = 3
#
# node-2 = 4
#
# **Output-2:**
#
# The distance between the two keys = 2

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None


def insert(root, value):
    if root is None:
        return TreeNode(value)
    
    if value < root.val:
        root.left = insert(root.left, value)
    else:
        root.right = insert(root.right, value)
    return root

def createBST(values):
    root = None
    for val in values:
        root = insert(root, val)
    return root

def findDistance(root, node1, node2):
    if root.val > node1 and root.val > node2:
        return findDistance(root.left, node1, node2)
    if root.val < node1 and root.val < node2:
        return findDistance(root.right, node1, node2)
    if root.val >= node1 and root.val <= node2:
        return distanceFromNode(root, node1) + distanceFromNode(root, node2)

def distanceFromNode(root, value, distance=0):
    if root.val == value:
        return distance
    elif root.val > value:
        return distanceFromNode(root.left, value, distance + 1)
    else:
        return distanceFromNode(root.right, value, distance + 1)

    

values = [8, 3, 1, 6, 4, 7, 10, 14, 13]
root = createBST(values)
node1 = 6
node2 = 14
distance = findDistance(root, node1, node2)
print("The distance between the two keys =", distance)
# Out:
# The distance between the two keys = 4

# %%
values = [8, 3, 1, 6, 4, 7, 10, 14,13]
root = createBST(values)
node1 = 3
node2 = 4
distance = findDistance(root, node1, node2)
print("The distance between the two keys =", distance)
# Out:
# The distance between the two keys = 2

# %% [markdown]
# <aside>
# 💡 Question-3:
#
# Write a program to convert a binary tree to a doubly linked list.
#
# Input:
#
#         10
#
#        /   \
#
#      5     20
#
#            /   \
#
#         30     35
#
# Output:
#
# 5 10 30 20 35
#
# </aside>

# %%
class Node:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

    
def convertToDLL(root):
    if root is None:
        return None
    
    # Convert left subtree to DLL
    if root.left:
        left_head = convertToDLL(root.left)
        left_tail = left_head.left
        
        left_tail.right = root
        root.left = left_tail
        root_head = left_head
    else:
        root_head = root

    # Convert right subtree to DLL
    if root.right:
        right_head = convertToDLL(root.right)
        right_tail = right_head.left
        
        root.right = right_head
        right_head.left = root
        root_tail = right_tail
    else:
        root_tail = root

    root_head.left = root_tail
    root_tail.right = root_head
    
    return root_head
    

def printDLL(head):
    current = head
    while current:
        print(current.val, end=" ")
        current = current.right
        if current == head:
            break

root = Node(10)
root.left = Node(5)
root.right = Node(20)
root.right.left = Node(30)
root.right.right = Node(35)

head = convertToDLL(root)

printDLL(head)
# Out:
# 5 10 30 20 35
